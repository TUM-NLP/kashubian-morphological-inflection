# %%
# %cd ~/morphological-inflection/data/data-preprocessing/preprocessing_to_json_or_tsv/src
# !ls ../../data/sigmorphon-data/
# Out:
# <path_to>/kashubian-morphological-inflection/predata-preprocessing_to_json_or_tsv/src
# ls: cannot access '../../2023InflectionST/part1/data/': No such file or directory

# %% [markdown]
# # Combine languages with *language code* or language word and convert to json

# %%
# old code
DATA_PATH = "<path_to>/kashubian-morphological-inflection/data/sigmorphon-data/"
OUT_DIR = "data/"
# LANGS = ["deu","eng"]
# TARGET_LANG = "deu_eng"
# LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"]
# TARGET_LANG = "mul"
LANGS_UNIQUE = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"]+["ote","pol","amh","csb"]
#TARGET_LANG = "mul_2"
LANGS_UNIQUE = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"]+["ote","pol","amh","csb"]
#LANGS_UNIQUE = ["ces","dsb","slk","pol"]
LANG_WORD_OF_CODE = {"grc":"Ancient Greek",
                  "dan": "Danish",
                  "fra":"French",
                  "sme":"Sámi",
                  "deu":"German",
                  "nav":"Navajo",
                  "jap":"Japanese",
                  "klr":"Khaling",
                  "eng":"English",
                  "ote":"Mezquital Otomi",
                  "pol":"Polish",
                  "amh":"Amharic",
                  "csb":"Kashubian"}

TARGET_LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng","ote","pol","amh","csb","mul"]
TARGET_LANGS = ["mkd","rus","bel"]
DATASET_COMPLETE = ["trn","tst","dev"]
LANGUAGE_CODES = [True,False]

print(OUT_DIR)
for target_lang in TARGET_LANGS:
    target_lang_initials = target_lang
    for lang_code in LANGUAGE_CODES:
        if lang_code: 
            target_lang = target_lang_initials  + "-lang-code"
        else: 
            target_lang = target_lang_initials  + "-lang-word"
            
        for dataset in DATASET_COMPLETE:
            if dataset != "tst" and  "csb" in target_lang: continue # csb only as test data
                
            OUT=OUT_DIR + target_lang  + "_" + dataset + ".json"
            with open (OUT,"w") as out_file:
                print(out_file)
                if target_lang in ["mul-lang-code","mul-lang-word"]: LANGS = LANGS_UNIQUE
                else: LANGS = [target_lang_initials]
                for lang in LANGS:
                    if dataset != "tst" and lang == "csb": continue # csb only as test data
                        
                    with open(DATA_PATH + lang + "." + dataset,"r") as in_file:
                        for line in in_file:
                            line = line.strip()
                            lemma, features, target = line.split("\t")
                            if lang_code: context = lang + ": "
                            else: context = LANG_WORD_OF_CODE[lang]+ ": "
                            json_line = f'{{"input": "{context}Inflect {lemma} | {features}","target": "{target}"}}'
                            out_file.write(json_line + "\n")
# Out:
# data/
# <_io.TextIOWrapper name='data/grc-lang-code_trn.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/grc-lang-code_tst.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/grc-lang-code_dev.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/grc-lang-word_trn.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/grc-lang-word_tst.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/grc-lang-word_dev.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/dan-lang-code_trn.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/dan-lang-code_tst.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/dan-lang-code_dev.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/dan-lang-word_trn.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/dan-lang-word_tst.json' mode='w' encoding='UTF-8'>
# ...

# %% [markdown]
# ## Combining the slavic training data

# %%
DATA_PATH = "<path_to>/kashubian-morphological-inflection/data/sigmorphon-data/"
OUT_DIR = "data/"
# LANGS = ["deu","eng"]
# TARGET_LANG = "deu_eng"
# LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"]
# TARGET_LANG = "mul"
LANGS_UNIQUE = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"]+["ote","pol","amh","csb"]
#TARGET_LANG = "mul_2"
LANGS_UNIQUE = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"]+["ote","pol","amh","csb"]
LANGS_SLAVIC_TRN = ["ces","dsb","slk","pol"] + ["mkd","rus","bel"]
LANG_WORD_OF_CODE = {"grc":"Ancient Greek",
                  "dan": "Danish",
                  "fra":"French",
                  "sme":"Sámi",
                  "deu":"German",
                  "nav":"Navajo",
                  "jap":"Japanese",
                  "klr":"Khaling",
                  "eng":"English",
                  "ote":"Mezquital Otomi",
                  "pol":"Polish",
                  "amh":"Amharic",
                  "csb":"Kashubian",
                    "ces":"Czech",
                    "dsb":"Lower Sorbian",
                    "slk": "Slovak",
                    "rus": "Russian",
                    "bel":"Belarusian",
                    "mkd":"Macedonian"}

TARGET_LANGS = ["slavic","slavic-word","slavic-family"]
TARGET_LANGS = ["slavic-distant","slavic-distant-word","slavic-distant-word-or-family"]
DATASET_COMPLETE = ["trn","tst","dev"]

print(OUT_DIR)
for target_lang in TARGET_LANGS:
        for dataset in DATASET_COMPLETE: 
            OUT=OUT_DIR + target_lang  + "_" + dataset + ".json"
            with open (OUT,"w") as out_file:
                print(out_file)
                LANGS = LANGS_SLAVIC_TRN
                for lang in LANGS:     
                    with open(DATA_PATH + lang + "." + dataset,"r") as in_file:
                        lines = in_file.readlines()
                        length = len(lines)
                        for i in range(length):
                            line = lines[i].strip()
                            prefix = "" if target_lang == TARGET_LANGS[0] else (LANG_WORD_OF_CODE[lang] + ": ") if target_lang == TARGET_LANGS[1] or (target_lang == TARGET_LANGS[2] and i < length/2) else "Slavic: "  
                            lemma, features, target = line.split("\t")
                            json_line = f'{{"input": "{prefix}Inflect {lemma} | {features}","target": "{target}"}}'
                            out_file.write(json_line + "\n")
# Out:
# data/
# <_io.TextIOWrapper name='data/slavic-distant_trn.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/slavic-distant_tst.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/slavic-distant_dev.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/slavic-distant-word_trn.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/slavic-distant-word_tst.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/slavic-distant-word_dev.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/slavic-distant-word-or-family_trn.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/slavic-distant-word-or-family_tst.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/slavic-distant-word-or-family_dev.json' mode='w' encoding='UTF-8'>

# %% [markdown]
# ## Get test data for Slavic languages using language word or family tag

# %%
DATA_PATH = "<path_to>/kashubian-logical-inflection/data/sigmorphon-data/"
OUT_DIR = "data/"
LANGS_UNIQUE = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"]+["ote","pol","amh","csb"]
#TARGET_LANG = "mul_2"
LANGS_UNIQUE = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"]+["ote","pol","amh","csb"]
LANGS_SLAVIC_TRN = ["ces","dsb","slk","pol","csb"]
LANGS =  ["mkd","rus","bel"]
LANG_WORD_OF_CODE = {"grc":"Ancient Greek",
                  "dan": "Danish",
                  "fra":"French",
                  "sme":"Sámi",
                  "deu":"German",
                  "nav":"Navajo",
                  "jap":"Japanese",
                  "klr":"Khaling",
                  "eng":"English",
                  "ote":"Mezquital Otomi",
                  "pol":"Polish",
                  "amh":"Amharic",
                  "csb":"Kashubian",
                    "ces":"Czech",
                    "dsb":"Lower Sorbian",
                    "slk": "Slovak",
                    "rus": "Russian",
                    "bel":"Belarusian",
                    "mkd":"Macedonian"
                    }

TARGET_LANGS = LANGS 
DATASET_COMPLETE = ["trn","tst","dev"]
CONTEXTS = ["","-lang-word","-word-or-family"]
print(OUT_DIR)
for context in CONTEXTS:
    for target_lang in TARGET_LANGS:
            for dataset in DATASET_COMPLETE: 
                if target_lang == "csb" and not dataset == "tst": continue
                OUT=OUT_DIR + target_lang + context + "_" + dataset + ".json"
                with open (OUT,"w") as out_file:
                    print(out_file)
                    with open(DATA_PATH + target_lang + "." + dataset,"r") as in_file:
                        lines = in_file.readlines()
                        length = len(lines)
                        for i in range(length):
                            line = lines[i].strip()
                            prefix = target_lang + ": " if context == "-lang-code" else LANG_WORD_OF_CODE[target_lang] + ": " if (context == "-lang-word" or (context == "-word-or-family" and i < length / 2)) else "Slavic: " if (context == "-family" or context == "-word-or-family") else ""
                            lemma, features, target = line.split("\t")
                            json_line = f'{{"input": "{prefix}Inflect {lemma} | {features}","target": "{target}"}}'
                            out_file.write(json_line + "\n")
# Out:
# data/
# <_io.TextIOWrapper name='data/mkd_trn.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/mkd_tst.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/mkd_dev.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/rus_trn.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/rus_tst.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/rus_dev.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/bel_trn.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/bel_tst.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/bel_dev.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/mkd-lang-word_trn.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/mkd-lang-word_tst.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/mkd-lang-word_dev.json' mode='w' encoding='UTF-8'>
# <_io.TextIOWrapper name='data/rus-lang-word_trn.json' mode='w' encoding='UTF-8'>
# ...

# %% [markdown]
# # Sub-sampling for the multilingual model
# In order to have the same amount of training data compared with the monolingual models, I sample 10000 forms for the training of 5lang-sample.
# + I sample from 5 languages 2000 forms and 200 forms for training and dev set respectively.
# + I sample 100, 200, 400, 600 tables from the given SIGMORPHON-UniMorph 2023 shared task data
# + I sample from the tables then the forms, keeping the forms per lemma together

# %%
from random import sample,shuffle
from math import floor
from itertools import groupby

def get_lemma(line):
    lemma = line.split("\t")[0]
    return lemma

def to_json_format (line, prefix):
    lemma, features, target = line.split("\t")
    json_line = f'{{"input": "{prefix}Inflect {lemma} | {features}","target": "{target}"}}'
    return json_line
    
LANGS = {"nav":"Navajo", "deu":"German", "klr":"Khaling", "amh":"Amharic", "grc":"Ancient Greek"}
PATH_DATA = "../../data/sigmorphon-data/"
OUTDIR = "data/"
SPLIT_DATASETS = [".tst",".trn",".dev"]
target_lang = "5lang-sample" # sample from the 5 languages with language name as prefix
with open (OUTDIR + target_lang + "_trn.json", "w") as trn_out, open (OUTDIR + target_lang + "_tst.json", "w") as tst_out, open (OUTDIR + target_lang + "_dev.json", "w") as dev_out:
    for lang in LANGS.keys():
            with open (PATH_DATA + lang + ".trn","r") as train_data, open (PATH_DATA + lang + ".dev","r") as dev_data,open (PATH_DATA + lang + ".tst","r") as test_data:
                data_lines = [line.strip() for line in train_data.readlines() + dev_data.readlines() + test_data.readlines()]

                tables = [(k, list(g)) for k, g in groupby(data_lines, get_lemma) if k != ""]
                
                for n in (500/len(LANGS) ,1000/len(LANGS) ,2000/len(LANGS) ,3000/len(LANGS) ):
                    sampled_tables = sample(tables,int(n))
                    size = len(sampled_tables)
                    datasets = [ sampled_tables[:floor(0.8*size)], sampled_tables[floor(0.8*size):floor(0.9*size)], sampled_tables[floor(0.9*size):] ]
    
                    train_forms = [form for lemma,table in datasets[0] for form in table]
                    dev_forms = [form for lemma,table in datasets[1] for form in table]
                    test_forms = [form for lemma,table in datasets[2] for form in table]
    
                    if len(dev_forms) < 1000/len(LANGS) or len(test_forms) < 1000/len(LANGS) or len(train_forms) < 10000/len(LANGS):
                        print(f"more tables than {n} needed for lang: {lang} ",len(dev_forms),len(test_forms) ,len(train_forms))
                    else:
                        print(f"{lang} needed {n} tables.")
                        break
                        
    
                # sampling and retaining order of the forms
                indices_train = sorted(sample(range(len(train_forms)), int(10000/len(LANGS)) ))
                indices_dev =  sorted(sample(range(len(dev_forms)), int(1000/len(LANGS)) ))
                indices_test = sorted( sample(range(len(test_forms)), int(1000/len(LANGS)) ))
    
                train_samples = [to_json_format(train_forms[i],LANGS[lang]+": ") for i in indices_train]
                dev_samples = [to_json_format(dev_forms[i],LANGS[lang]+": ") for i in indices_dev]
                test_samples = [to_json_format(test_forms[i],LANGS[lang]+": ") for i in indices_test]

                train_txt = "\n".join(train_samples) + "\n"
                dev_txt = "\n".join(dev_samples) + "\n"
                test_txt = "\n".join(test_samples) + "\n"
    
                trn_out.write(train_txt)
                dev_out.write(dev_txt)
                tst_out.write(test_txt)
# Out:
# nav needed 100.0 tables.
# more tables than 100.0 needed for lang: deu  118 127 965
# more tables than 200.0 needed for lang: deu  247 247 1924
# deu needed 400.0 tables.
# more tables than 100.0 needed for lang: klr  245 240 1930
# klr needed 200.0 tables.
# more tables than 100.0 needed for lang: amh  145 145 953
# more tables than 200.0 needed for lang: amh  238 237 1864
# amh needed 400.0 tables.
# more tables than 100.0 needed for lang: grc  173 243 2036
# grc needed 200.0 tables.

# %% [markdown]
# # 3 Slavic Models
# Training Languages: Polish, Czech, Slovak, and Lower Sorbian. (10K examples)
# Training Languages: Polish, Czech, Slovak, and Lower Sorbian. (10K examples)
# 1. Base multilingual: usual training combining all 5 languages (no language name in the prompt)
# 2. Multilingual with language name (lang-word): training combining all 5 languages where the prompt specifies the name of the language
# 3. Multilingual with language family (lang-family): all 5 languages, but half of the time with the language name (as in 2) but the other half of the time mentioning 'Slavic' instead of the language name

# %%
TARGET_LANGS = ["slavic"]
INPUT_LANGS = ["pol","dsb","slk","ces","csb"]
DATASETS = [".trn",".tst",".dev"]
DATA_PATH = "<path_to>/kashubian-morphological-inflection/data/sigmorphon-data/"
for target_lang in TARGET_LANGS:
    for dataset in DATASETS:
        out_path = DATA_PATH + target_lang + dataset
        with open (out_path,"w") as out_file:
            print("write: ",out_path)
            for input_lang in INPUT_LANGS:
                if input_lang == "csb" and dataset != ".tst": continue # include csb only in test set
                in_path = DATA_PATH + input_lang + dataset
                with open (in_path,"r") as in_file:
                    print("read:",in_path)
                    out_file.write(in_file.read())

# %% [markdown]
# # Converting LLM generated Kashubian data into .tsv format

# %%
def get_lemma(line):
	lemma = line.split("\t")[0]
	return lemma
def get_features(line):
	features = line.split("\t")[1]
	return features
def get_word(line):
	word = line.strip().split("\t")[2]
	return word
in_path = {
	"trn": "<path_to>/kashubian-morphological-inflection/llm/data/gemini-2.5-flash/csb.trn",
	"dev": "<path_to>/kashubian-logical-inflection/llm/data/gemini-2.5-flash/csb.dev"
}
out_path = {
	"trn": "../data/csb-gemini_trn.tsv",
	"dev": "../data/csb-gemini_dev.tsv"
}
for dataset in in_path.keys():
	with open (in_path[dataset], "r") as in_file, open(out_path[dataset],"w") as out_file:
		print(out_path[dataset])
		lines = in_file.readlines()
		for l in lines:
			line = l.strip()
			assert(len(line.split("\t"))==3)
			lemma, features, target = get_lemma(line), get_features(line), get_word(line)
			tsv_line = f'Inflect {lemma} | {features}\t{target}\n'
			out_file.write(tsv_line)
# Out:
# ../data/csb-gemini_trn.tsv
# ../data/csb-gemini_dev.tsv

# %% [markdown]
# Polish data to -> tsv

# %%
def get_lemma(line):
	lemma = line.split("\t")[0]
	return lemma
def get_features(line):
	features = line.split("\t")[1]
	return features
def get_word(line):
	word = line.strip().split("\t")[2]
	return word

in_path = {
	"trn": "<path_to>/kashubian-morphological-inflection/data/sigmorphon-data/pol.trn",
	"dev": "<path_to>/kashubian-morphological-inflection/data/sigmorphon-data/pol.dev"
}
out_path = {
	"trn": "../data/pol_trn.tsv",
	"dev": "../data/pol_dev.tsv"
}
for dataset in in_path.keys():
	with open (in_path[dataset], "r") as in_file, open(out_path[dataset],"w") as out_file:
		print(out_path[dataset])
		lines = in_file.readlines()
		for l in lines:
			line = l.strip()
			assert(len(line.split("\t"))==3)
			lemma, features, target = get_lemma(line), get_features(line), get_word(line)
			tsv_line = f'Inflect {lemma} | {features}\t{target}\n'
			out_file.write(tsv_line)
# Out:
# ../data/pol_trn.tsv
# ../data/pol_dev.tsv
